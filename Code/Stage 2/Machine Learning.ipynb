# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import log_loss
from collections import Counter

# %%
filepath='/Users/DanLo1108/Documents/Projects/NCAA Tournament Project/Data/'

# %%
training_data = pd.read_csv(filepath + 'final_training_data.csv')
testing_data = pd.read_csv(filepath + 'final_testing_data.csv')

# %%
X_train = training_data.drop('result',axis=1)
y_train = training_data.result

X_test = testing_data.drop(['team_1','team_2'],axis=1)

# %%
#Drop null values from train data
def dropnan(df1, df2,features):
    for feat in features:
        inds=df1[pd.notnull(df1[feat])].index.values
        df1=df1.ix[inds]
        df2=df2.ix[inds]
    return df1,df2

X_train,y_train=dropnan(X_train,y_train,X_train.columns.tolist())
#X_test,y_test=dropnan(X_test,y_test,X_test.columns.tolist())

weights = np.array(X_train.game_weight)
X_train=X_train.drop('game_weight',axis=1)

# %%
matchups=[]
for ind in testing_data.index.values:
    x=testing_data.ix[ind]
    matchups.append((x.team_1,x.team_2))

# %%
matchups
# Out:
# [('Villanova', 'Virginia'),
#  ('Villanova', 'Oklahoma'),
#  ('Villanova', 'Louisville'),
#  ('Villanova', 'Northern Iowa'),
#  ('Villanova', 'Providence'),
#  ('Villanova', 'Michigan St'),
#  ('Villanova', 'NC State'),
#  ('Villanova', 'LSU'),
#  ('Villanova', 'Georgia'),
#  ('Villanova', 'Boise St'),
#  ('Villanova', 'Dayton'),
#  ('Villanova', 'Wyoming'),
#  ('Villanova', 'UC Irvine'),
#  ('Villanova', 'Albany NY'),
#  ('Villanova', 'Belmont'),
#  ('Villanova', 'Lafayette'),
#  ('Villanova', 'Duke'),
#  ('Villanova', 'Gonzaga'),
#  ('Villanova', 'Iowa St'),
#  ('Villanova', 'Georgetown'),
#  ('Villanova', 'Utah'),
#  ('Villanova', 'SMU'),
#  ('Villanova', 'Iowa'),
#  ('Villanova', 'San Diego St'),
#  ('Villanova', "St John's"),
#  ('Villanova', 'Davidson'),
#  ('Villanova', 'UCLA'),
#  ('Villanova', 'SF Austin'),
#  ('Villanova', 'E Washington'),
#  ('Villanova', 'UAB'),
#  ('Villanova', 'N Dakota St'),
#  ('Villanova', 'North Florida'),
#  ('Villanova', 'Robert Morris'),
#  ('Villanova', 'Kentucky'),
#  ('Villanova', 'Kansas'),
#  ('Villanova', 'Notre Dame'),
#  ('Villanova', 'Maryland'),
#  ('Villanova', 'West Virginia'),
#  ('Villanova', 'Butler'),
#  ('Villanova', 'Wichita St'),
#  ('Villanova', 'Cincinnati'),
#  ('Villanova', 'Purdue'),
#  ('Villanova', 'Indiana'),
#  ('Villanova', 'Texas'),
#  ('Villanova', 'Buffalo'),
#  ('Villanova', 'Valparaiso'),
#  ('Villanova', 'Northeastern'),
#  ('Villanova', 'New Mexico St'),
#  ('Villanova', 'Hampton'),
#  ('Villanova', 'Manhattan'),
#  ('Villanova', 'Wisconsin'),
#  ('Villanova', 'Arizona'),
#  ('Villanova', 'Baylor'),
#  ('Villanova', 'North Carolina'),
#  ('Villanova', 'Arkansas'),
#  ('Villanova', 'Xavier'),
#  ('Villanova', 'VA Commonwealth'),
#  ('Villanova', 'Oregon'),
#  ('Villanova', 'Oklahoma St'),
#  ('Villanova', 'Ohio St'),
#  ('Villanova', 'BYU'),
#  ('Villanova', 'Mississippi'),
#  ('Villanova', 'Wofford'),
#  ('Villanova', 'Harvard'),
#  ('Villanova', 'Georgia St'),
#  ('Villanova', 'TX Southern'),
#  ('Villanova', 'Coastal Car'),
#  ('Virginia', 'Oklahoma'),
#  ('Virginia', 'Louisville'),
#  ('Virginia', 'Northern Iowa'),
#  ('Virginia', 'Providence'),
#  ('Virginia', 'Michigan St'),
#  ('Virginia', 'NC State'),
#  ('Virginia', 'LSU'),
#  ('Virginia', 'Georgia'),
#  ('Virginia', 'Boise St'),
#  ('Virginia', 'Dayton'),
#  ('Virginia', 'Wyoming'),
#  ('Virginia', 'UC Irvine'),
#  ('Virginia', 'Albany NY'),
#  ('Virginia', 'Belmont'),
#  ('Virginia', 'Lafayette'),
#  ('Virginia', 'Duke'),
#  ('Virginia', 'Gonzaga'),
#  ('Virginia', 'Iowa St'),
#  ('Virginia', 'Georgetown'),
#  ('Virginia', 'Utah'),
#  ('Virginia', 'SMU'),
#  ('Virginia', 'Iowa'),
#  ('Virginia', 'San Diego St'),
#  ('Virginia', "St John's"),
#  ('Virginia', 'Davidson'),
#  ('Virginia', 'UCLA'),
#  ('Virginia', 'SF Austin'),
#  ('Virginia', 'E Washington'),
#  ('Virginia', 'UAB'),
#  ('Virginia', 'N Dakota St'),
#  ('Virginia', 'North Florida'),
#  ('Virginia', 'Robert Morris'),
#  ('Virginia', 'Kentucky'),
#  ('Virginia', 'Kansas'),
#  ('Virginia', 'Notre Dame'),
#  ('Virginia', 'Maryland'),
#  ('Virginia', 'West Virginia'),
#  ('Virginia', 'Butler'),
#  ('Virginia', 'Wichita St'),
#  ('Virginia', 'Cincinnati'),
#  ('Virginia', 'Purdue'),
#  ('Virginia', 'Indiana'),
#  ('Virginia', 'Texas'),
#  ('Virginia', 'Buffalo'),
#  ('Virginia', 'Valparaiso'),
#  ('Virginia', 'Northeastern'),
#  ('Virginia', 'New Mexico St'),
#  ('Virginia', 'Hampton'),
#  ('Virginia', 'Manhattan'),
#  ('Virginia', 'Wisconsin'),
#  ('Virginia', 'Arizona'),
#  ('Virginia', 'Baylor'),
#  ('Virginia', 'North Carolina'),
#  ('Virginia', 'Arkansas'),
#  ('Virginia', 'Xavier'),
#  ('Virginia', 'VA Commonwealth'),
#  ('Virginia', 'Oregon'),
#  ('Virginia', 'Oklahoma St'),
#  ('Virginia', 'Ohio St'),
#  ('Virginia', 'BYU'),
#  ('Virginia', 'Mississippi'),
#  ('Virginia', 'Wofford'),
#  ('Virginia', 'Harvard'),
#  ('Virginia', 'Georgia St'),
#  ('Virginia', 'TX Southern'),
#  ('Virginia', 'Coastal Car'),
#  ('Oklahoma', 'Louisville'),
#  ('Oklahoma', 'Northern Iowa'),
#  ('Oklahoma', 'Providence'),
#  ('Oklahoma', 'Michigan St'),
#  ('Oklahoma', 'NC State'),
#  ('Oklahoma', 'LSU'),
#  ('Oklahoma', 'Georgia'),
#  ('Oklahoma', 'Boise St'),
#  ('Oklahoma', 'Dayton'),
#  ('Oklahoma', 'Wyoming'),
#  ('Oklahoma', 'UC Irvine'),
#  ('Oklahoma', 'Albany NY'),
#  ('Oklahoma', 'Belmont'),
#  ('Oklahoma', 'Lafayette'),
#  ('Oklahoma', 'Duke'),
#  ('Oklahoma', 'Gonzaga'),
#  ('Oklahoma', 'Iowa St'),
#  ('Oklahoma', 'Georgetown'),
#  ('Oklahoma', 'Utah'),
#  ('Oklahoma', 'SMU'),
#  ('Oklahoma', 'Iowa'),
#  ('Oklahoma', 'San Diego St'),
#  ('Oklahoma', "St John's"),
#  ('Oklahoma', 'Davidson'),
#  ('Oklahoma', 'UCLA'),
#  ('Oklahoma', 'SF Austin'),
#  ('Oklahoma', 'E Washington'),
#  ('Oklahoma', 'UAB'),
#  ('Oklahoma', 'N Dakota St'),
#  ('Oklahoma', 'North Florida'),
#  ('Oklahoma', 'Robert Morris'),
#  ('Oklahoma', 'Kentucky'),
#  ('Oklahoma', 'Kansas'),
#  ('Oklahoma', 'Notre Dame'),
#  ('Oklahoma', 'Maryland'),
#  ('Oklahoma', 'West Virginia'),
#  ('Oklahoma', 'Butler'),
#  ('Oklahoma', 'Wichita St'),
#  ('Oklahoma', 'Cincinnati'),
#  ('Oklahoma', 'Purdue'),
#  ('Oklahoma', 'Indiana'),
#  ('Oklahoma', 'Texas'),
#  ('Oklahoma', 'Buffalo'),
#  ('Oklahoma', 'Valparaiso'),
#  ('Oklahoma', 'Northeastern'),
#  ('Oklahoma', 'New Mexico St'),
#  ('Oklahoma', 'Hampton'),
#  ('Oklahoma', 'Manhattan'),
#  ('Oklahoma', 'Wisconsin'),
#  ('Oklahoma', 'Arizona'),
#  ('Oklahoma', 'Baylor'),
#  ('Oklahoma', 'North Carolina'),
#  ('Oklahoma', 'Arkansas'),
#  ('Oklahoma', 'Xavier'),
#  ('Oklahoma', 'VA Commonwealth'),
#  ('Oklahoma', 'Oregon'),
#  ('Oklahoma', 'Oklahoma St'),
#  ('Oklahoma', 'Ohio St'),
#  ('Oklahoma', 'BYU'),
#  ('Oklahoma', 'Mississippi'),
#  ('Oklahoma', 'Wofford'),
#  ('Oklahoma', 'Harvard'),
#  ('Oklahoma', 'Georgia St'),
#  ('Oklahoma', 'TX Southern'),
#  ('Oklahoma', 'Coastal Car'),
#  ('Louisville', 'Northern Iowa'),
#  ('Louisville', 'Providence'),
#  ('Louisville', 'Michigan St'),
#  ('Louisville', 'NC State'),
#  ('Louisville', 'LSU'),
#  ('Louisville', 'Georgia'),
#  ('Louisville', 'Boise St'),
#  ('Louisville', 'Dayton'),
#  ('Louisville', 'Wyoming'),
#  ('Louisville', 'UC Irvine'),
#  ('Louisville', 'Albany NY'),
#  ('Louisville', 'Belmont'),
#  ('Louisville', 'Lafayette'),
#  ('Louisville', 'Duke'),
#  ('Louisville', 'Gonzaga'),
#  ('Louisville', 'Iowa St'),
#  ('Louisville', 'Georgetown'),
#  ('Louisville', 'Utah'),
#  ('Louisville', 'SMU'),
#  ('Louisville', 'Iowa'),
#  ('Louisville', 'San Diego St'),
#  ('Louisville', "St John's"),
#  ('Louisville', 'Davidson'),
#  ('Louisville', 'UCLA'),
#  ('Louisville', 'SF Austin'),
#  ('Louisville', 'E Washington'),
#  ('Louisville', 'UAB'),
#  ('Louisville', 'N Dakota St'),
#  ('Louisville', 'North Florida'),
#  ('Louisville', 'Robert Morris'),
#  ('Louisville', 'Kentucky'),
#  ('Louisville', 'Kansas'),
#  ('Louisville', 'Notre Dame'),
#  ('Louisville', 'Maryland'),
#  ('Louisville', 'West Virginia'),
#  ('Louisville', 'Butler'),
#  ('Louisville', 'Wichita St'),
#  ('Louisville', 'Cincinnati'),
#  ('Louisville', 'Purdue'),
#  ('Louisville', 'Indiana'),
#  ('Louisville', 'Texas'),
#  ('Louisville', 'Buffalo'),
#  ('Louisville', 'Valparaiso'),
#  ('Louisville', 'Northeastern'),
#  ('Louisville', 'New Mexico St'),
#  ('Louisville', 'Hampton'),
#  ('Louisville', 'Manhattan'),
#  ('Louisville', 'Wisconsin'),
#  ('Louisville', 'Arizona'),
#  ('Louisville', 'Baylor'),
#  ('Louisville', 'North Carolina'),
#  ('Louisville', 'Arkansas'),
#  ('Louisville', 'Xavier'),
#  ('Louisville', 'VA Commonwealth'),
#  ('Louisville', 'Oregon'),
#  ('Louisville', 'Oklahoma St'),
#  ('Louisville', 'Ohio St'),
#  ('Louisville', 'BYU'),
#  ('Louisville', 'Mississippi'),
#  ('Louisville', 'Wofford'),
#  ('Louisville', 'Harvard'),
#  ('Louisville', 'Georgia St'),
#  ('Louisville', 'TX Southern'),
#  ('Louisville', 'Coastal Car'),
#  ('Northern Iowa', 'Providence'),
#  ('Northern Iowa', 'Michigan St'),
#  ('Northern Iowa', 'NC State'),
#  ('Northern Iowa', 'LSU'),
#  ('Northern Iowa', 'Georgia'),
#  ('Northern Iowa', 'Boise St'),
#  ('Northern Iowa', 'Dayton'),
#  ('Northern Iowa', 'Wyoming'),
#  ('Northern Iowa', 'UC Irvine'),
#  ('Northern Iowa', 'Albany NY'),
#  ('Northern Iowa', 'Belmont'),
#  ('Northern Iowa', 'Lafayette'),
#  ('Northern Iowa', 'Duke'),
#  ('Northern Iowa', 'Gonzaga'),
#  ('Northern Iowa', 'Iowa St'),
#  ('Northern Iowa', 'Georgetown'),
#  ('Northern Iowa', 'Utah'),
#  ('Northern Iowa', 'SMU'),
#  ('Northern Iowa', 'Iowa'),
#  ('Northern Iowa', 'San Diego St'),
#  ('Northern Iowa', "St John's"),
#  ('Northern Iowa', 'Davidson'),
#  ('Northern Iowa', 'UCLA'),
#  ('Northern Iowa', 'SF Austin'),
#  ('Northern Iowa', 'E Washington'),
#  ('Northern Iowa', 'UAB'),
#  ('Northern Iowa', 'N Dakota St'),
#  ('Northern Iowa', 'North Florida'),
#  ('Northern Iowa', 'Robert Morris'),
#  ('Northern Iowa', 'Kentucky'),
#  ('Northern Iowa', 'Kansas'),
#  ('Northern Iowa', 'Notre Dame'),
#  ('Northern Iowa', 'Maryland'),
#  ('Northern Iowa', 'West Virginia'),
#  ('Northern Iowa', 'Butler'),
#  ('Northern Iowa', 'Wichita St'),
#  ('Northern Iowa', 'Cincinnati'),
#  ('Northern Iowa', 'Purdue'),
#  ('Northern Iowa', 'Indiana'),
#  ('Northern Iowa', 'Texas'),
#  ('Northern Iowa', 'Buffalo'),
#  ('Northern Iowa', 'Valparaiso'),
#  ('Northern Iowa', 'Northeastern'),
#  ('Northern Iowa', 'New Mexico St'),
#  ('Northern Iowa', 'Hampton'),
#  ('Northern Iowa', 'Manhattan'),
#  ('Northern Iowa', 'Wisconsin'),
#  ('Northern Iowa', 'Arizona'),
#  ('Northern Iowa', 'Baylor'),
#  ('Northern Iowa', 'North Carolina'),
#  ('Northern Iowa', 'Arkansas'),
#  ('Northern Iowa', 'Xavier'),
#  ('Northern Iowa', 'VA Commonwealth'),
#  ('Northern Iowa', 'Oregon'),
#  ('Northern Iowa', 'Oklahoma St'),
#  ('Northern Iowa', 'Ohio St'),
#  ('Northern Iowa', 'BYU'),
#  ('Northern Iowa', 'Mississippi'),
#  ('Northern Iowa', 'Wofford'),
#  ('Northern Iowa', 'Harvard'),
#  ('Northern Iowa', 'Georgia St'),
#  ('Northern Iowa', 'TX Southern'),
#  ('Northern Iowa', 'Coastal Car'),
#  ('Providence', 'Michigan St'),
#  ('Providence', 'NC State'),
#  ('Providence', 'LSU'),
#  ('Providence', 'Georgia'),
#  ('Providence', 'Boise St'),
#  ('Providence', 'Dayton'),
#  ('Providence', 'Wyoming'),
#  ('Providence', 'UC Irvine'),
#  ('Providence', 'Albany NY'),
#  ('Providence', 'Belmont'),
#  ('Providence', 'Lafayette'),
#  ('Providence', 'Duke'),
#  ('Providence', 'Gonzaga'),
#  ('Providence', 'Iowa St'),
#  ('Providence', 'Georgetown'),
#  ('Providence', 'Utah'),
#  ('Providence', 'SMU'),
#  ('Providence', 'Iowa'),
#  ('Providence', 'San Diego St'),
#  ('Providence', "St John's"),
#  ('Providence', 'Davidson'),
#  ('Providence', 'UCLA'),
#  ('Providence', 'SF Austin'),
#  ('Providence', 'E Washington'),
#  ('Providence', 'UAB'),
#  ('Providence', 'N Dakota St'),
#  ('Providence', 'North Florida'),
#  ('Providence', 'Robert Morris'),
#  ('Providence', 'Kentucky'),
#  ('Providence', 'Kansas'),
#  ('Providence', 'Notre Dame'),
#  ('Providence', 'Maryland'),
#  ('Providence', 'West Virginia'),
#  ('Providence', 'Butler'),
#  ('Providence', 'Wichita St'),
#  ('Providence', 'Cincinnati'),
#  ('Providence', 'Purdue'),
#  ('Providence', 'Indiana'),
#  ('Providence', 'Texas'),
#  ('Providence', 'Buffalo'),
#  ('Providence', 'Valparaiso'),
#  ('Providence', 'Northeastern'),
#  ('Providence', 'New Mexico St'),
#  ('Providence', 'Hampton'),
#  ('Providence', 'Manhattan'),
#  ('Providence', 'Wisconsin'),
#  ('Providence', 'Arizona'),
#  ('Providence', 'Baylor'),
#  ('Providence', 'North Carolina'),
#  ('Providence', 'Arkansas'),
#  ('Providence', 'Xavier'),
#  ('Providence', 'VA Commonwealth'),
#  ('Providence', 'Oregon'),
#  ('Providence', 'Oklahoma St'),
#  ('Providence', 'Ohio St'),
#  ('Providence', 'BYU'),
#  ('Providence', 'Mississippi'),
#  ('Providence', 'Wofford'),
#  ('Providence', 'Harvard'),
#  ('Providence', 'Georgia St'),
#  ('Providence', 'TX Southern'),
#  ('Providence', 'Coastal Car'),
#  ('Michigan St', 'NC State'),
#  ('Michigan St', 'LSU'),
#  ('Michigan St', 'Georgia'),
#  ('Michigan St', 'Boise St'),
#  ('Michigan St', 'Dayton'),
#  ('Michigan St', 'Wyoming'),
#  ('Michigan St', 'UC Irvine'),
#  ('Michigan St', 'Albany NY'),
#  ('Michigan St', 'Belmont'),
#  ('Michigan St', 'Lafayette'),
#  ('Michigan St', 'Duke'),
#  ('Michigan St', 'Gonzaga'),
#  ('Michigan St', 'Iowa St'),
#  ('Michigan St', 'Georgetown'),
#  ('Michigan St', 'Utah'),
#  ('Michigan St', 'SMU'),
#  ('Michigan St', 'Iowa'),
#  ('Michigan St', 'San Diego St'),
#  ('Michigan St', "St John's"),
#  ('Michigan St', 'Davidson'),
#  ('Michigan St', 'UCLA'),
#  ('Michigan St', 'SF Austin'),
#  ('Michigan St', 'E Washington'),
#  ('Michigan St', 'UAB'),
#  ('Michigan St', 'N Dakota St'),
#  ('Michigan St', 'North Florida'),
#  ('Michigan St', 'Robert Morris'),
#  ('Michigan St', 'Kentucky'),
#  ('Michigan St', 'Kansas'),
#  ('Michigan St', 'Notre Dame'),
#  ('Michigan St', 'Maryland'),
#  ('Michigan St', 'West Virginia'),
#  ('Michigan St', 'Butler'),
#  ('Michigan St', 'Wichita St'),
#  ('Michigan St', 'Cincinnati'),
#  ('Michigan St', 'Purdue'),
#  ('Michigan St', 'Indiana'),
#  ('Michigan St', 'Texas'),
#  ('Michigan St', 'Buffalo'),
#  ('Michigan St', 'Valparaiso'),
#  ('Michigan St', 'Northeastern'),
#  ('Michigan St', 'New Mexico St'),
#  ('Michigan St', 'Hampton'),
#  ('Michigan St', 'Manhattan'),
#  ('Michigan St', 'Wisconsin'),
#  ('Michigan St', 'Arizona'),
#  ('Michigan St', 'Baylor'),
#  ('Michigan St', 'North Carolina'),
#  ('Michigan St', 'Arkansas'),
#  ('Michigan St', 'Xavier'),
#  ('Michigan St', 'VA Commonwealth'),
#  ('Michigan St', 'Oregon'),
#  ('Michigan St', 'Oklahoma St'),
#  ('Michigan St', 'Ohio St'),
#  ('Michigan St', 'BYU'),
#  ('Michigan St', 'Mississippi'),
#  ('Michigan St', 'Wofford'),
#  ('Michigan St', 'Harvard'),
#  ('Michigan St', 'Georgia St'),
#  ('Michigan St', 'TX Southern'),
#  ('Michigan St', 'Coastal Car'),
#  ('NC State', 'LSU'),
#  ('NC State', 'Georgia'),
#  ('NC State', 'Boise St'),
#  ('NC State', 'Dayton'),
#  ('NC State', 'Wyoming'),
#  ('NC State', 'UC Irvine'),
#  ('NC State', 'Albany NY'),
#  ('NC State', 'Belmont'),
#  ('NC State', 'Lafayette'),
#  ('NC State', 'Duke'),
#  ('NC State', 'Gonzaga'),
#  ('NC State', 'Iowa St'),
#  ('NC State', 'Georgetown'),
#  ('NC State', 'Utah'),
#  ('NC State', 'SMU'),
#  ('NC State', 'Iowa'),
#  ('NC State', 'San Diego St'),
#  ('NC State', "St John's"),
#  ('NC State', 'Davidson'),
#  ('NC State', 'UCLA'),
#  ('NC State', 'SF Austin'),
#  ('NC State', 'E Washington'),
#  ('NC State', 'UAB'),
#  ('NC State', 'N Dakota St'),
#  ('NC State', 'North Florida'),
#  ('NC State', 'Robert Morris'),
#  ('NC State', 'Kentucky'),
#  ('NC State', 'Kansas'),
#  ('NC State', 'Notre Dame'),
#  ('NC State', 'Maryland'),
#  ('NC State', 'West Virginia'),
#  ('NC State', 'Butler'),
#  ('NC State', 'Wichita St'),
#  ('NC State', 'Cincinnati'),
#  ('NC State', 'Purdue'),
#  ('NC State', 'Indiana'),
#  ('NC State', 'Texas'),
#  ('NC State', 'Buffalo'),
#  ('NC State', 'Valparaiso'),
#  ('NC State', 'Northeastern'),
#  ('NC State', 'New Mexico St'),
#  ('NC State', 'Hampton'),
#  ('NC State', 'Manhattan'),
#  ('NC State', 'Wisconsin'),
#  ('NC State', 'Arizona'),
#  ('NC State', 'Baylor'),
#  ('NC State', 'North Carolina'),
#  ('NC State', 'Arkansas'),
#  ('NC State', 'Xavier'),
#  ('NC State', 'VA Commonwealth'),
#  ('NC State', 'Oregon'),
#  ('NC State', 'Oklahoma St'),
#  ('NC State', 'Ohio St'),
#  ('NC State', 'BYU'),
#  ('NC State', 'Mississippi'),
#  ('NC State', 'Wofford'),
#  ('NC State', 'Harvard'),
#  ('NC State', 'Georgia St'),
#  ('NC State', 'TX Southern'),
#  ('NC State', 'Coastal Car'),
#  ('LSU', 'Georgia'),
#  ('LSU', 'Boise St'),
#  ('LSU', 'Dayton'),
#  ('LSU', 'Wyoming'),
#  ('LSU', 'UC Irvine'),
#  ('LSU', 'Albany NY'),
#  ('LSU', 'Belmont'),
#  ('LSU', 'Lafayette'),
#  ('LSU', 'Duke'),
#  ('LSU', 'Gonzaga'),
#  ('LSU', 'Iowa St'),
#  ('LSU', 'Georgetown'),
#  ('LSU', 'Utah'),
#  ('LSU', 'SMU'),
#  ('LSU', 'Iowa'),
#  ('LSU', 'San Diego St'),
#  ('LSU', "St John's"),
#  ('LSU', 'Davidson'),
#  ('LSU', 'UCLA'),
#  ('LSU', 'SF Austin'),
#  ('LSU', 'E Washington'),
#  ('LSU', 'UAB'),
#  ('LSU', 'N Dakota St'),
#  ('LSU', 'North Florida'),
#  ('LSU', 'Robert Morris'),
#  ('LSU', 'Kentucky'),
#  ('LSU', 'Kansas'),
#  ('LSU', 'Notre Dame'),
#  ('LSU', 'Maryland'),
#  ('LSU', 'West Virginia'),
#  ('LSU', 'Butler'),
#  ('LSU', 'Wichita St'),
#  ('LSU', 'Cincinnati'),
#  ('LSU', 'Purdue'),
#  ('LSU', 'Indiana'),
#  ('LSU', 'Texas'),
#  ('LSU', 'Buffalo'),
#  ('LSU', 'Valparaiso'),
#  ('LSU', 'Northeastern'),
#  ('LSU', 'New Mexico St'),
#  ('LSU', 'Hampton'),
#  ('LSU', 'Manhattan'),
#  ('LSU', 'Wisconsin'),
#  ('LSU', 'Arizona'),
#  ('LSU', 'Baylor'),
#  ('LSU', 'North Carolina'),
#  ('LSU', 'Arkansas'),
#  ('LSU', 'Xavier'),
#  ('LSU', 'VA Commonwealth'),
#  ('LSU', 'Oregon'),
#  ('LSU', 'Oklahoma St'),
#  ('LSU', 'Ohio St'),
#  ('LSU', 'BYU'),
#  ('LSU', 'Mississippi'),
#  ('LSU', 'Wofford'),
#  ('LSU', 'Harvard'),
#  ('LSU', 'Georgia St'),
#  ('LSU', 'TX Southern'),
#  ('LSU', 'Coastal Car'),
#  ('Georgia', 'Boise St'),
#  ('Georgia', 'Dayton'),
#  ('Georgia', 'Wyoming'),
#  ('Georgia', 'UC Irvine'),
#  ('Georgia', 'Albany NY'),
#  ('Georgia', 'Belmont'),
#  ('Georgia', 'Lafayette'),
#  ('Georgia', 'Duke'),
#  ('Georgia', 'Gonzaga'),
#  ('Georgia', 'Iowa St'),
#  ('Georgia', 'Georgetown'),
#  ('Georgia', 'Utah'),
#  ('Georgia', 'SMU'),
#  ('Georgia', 'Iowa'),
#  ('Georgia', 'San Diego St'),
#  ('Georgia', "St John's"),
#  ('Georgia', 'Davidson'),
#  ('Georgia', 'UCLA'),
#  ('Georgia', 'SF Austin'),
#  ('Georgia', 'E Washington'),
#  ('Georgia', 'UAB'),
#  ('Georgia', 'N Dakota St'),
#  ('Georgia', 'North Florida'),
#  ('Georgia', 'Robert Morris'),
#  ('Georgia', 'Kentucky'),
#  ('Georgia', 'Kansas'),
#  ('Georgia', 'Notre Dame'),
#  ('Georgia', 'Maryland'),
#  ('Georgia', 'West Virginia'),
#  ('Georgia', 'Butler'),
#  ('Georgia', 'Wichita St'),
#  ('Georgia', 'Cincinnati'),
#  ('Georgia', 'Purdue'),
#  ('Georgia', 'Indiana'),
#  ('Georgia', 'Texas'),
#  ('Georgia', 'Buffalo'),
#  ('Georgia', 'Valparaiso'),
#  ('Georgia', 'Northeastern'),
#  ('Georgia', 'New Mexico St'),
#  ('Georgia', 'Hampton'),
#  ('Georgia', 'Manhattan'),
#  ('Georgia', 'Wisconsin'),
#  ('Georgia', 'Arizona'),
#  ('Georgia', 'Baylor'),
#  ('Georgia', 'North Carolina'),
#  ('Georgia', 'Arkansas'),
#  ('Georgia', 'Xavier'),
#  ('Georgia', 'VA Commonwealth'),
#  ('Georgia', 'Oregon'),
#  ('Georgia', 'Oklahoma St'),
#  ('Georgia', 'Ohio St'),
#  ('Georgia', 'BYU'),
#  ('Georgia', 'Mississippi'),
#  ('Georgia', 'Wofford'),
#  ('Georgia', 'Harvard'),
#  ('Georgia', 'Georgia St'),
#  ('Georgia', 'TX Southern'),
#  ('Georgia', 'Coastal Car'),
#  ('Boise St', 'Dayton'),
#  ('Boise St', 'Wyoming'),
#  ('Boise St', 'UC Irvine'),
#  ('Boise St', 'Albany NY'),
#  ('Boise St', 'Belmont'),
#  ('Boise St', 'Lafayette'),
#  ('Boise St', 'Duke'),
#  ('Boise St', 'Gonzaga'),
#  ('Boise St', 'Iowa St'),
#  ('Boise St', 'Georgetown'),
#  ('Boise St', 'Utah'),
#  ('Boise St', 'SMU'),
#  ('Boise St', 'Iowa'),
#  ('Boise St', 'San Diego St'),
#  ('Boise St', "St John's"),
#  ('Boise St', 'Davidson'),
#  ('Boise St', 'UCLA'),
#  ('Boise St', 'SF Austin'),
#  ('Boise St', 'E Washington'),
#  ('Boise St', 'UAB'),
#  ('Boise St', 'N Dakota St'),
#  ('Boise St', 'North Florida'),
#  ('Boise St', 'Robert Morris'),
#  ('Boise St', 'Kentucky'),
#  ('Boise St', 'Kansas'),
#  ('Boise St', 'Notre Dame'),
#  ('Boise St', 'Maryland'),
#  ('Boise St', 'West Virginia'),
#  ('Boise St', 'Butler'),
#  ('Boise St', 'Wichita St'),
#  ('Boise St', 'Cincinnati'),
#  ('Boise St', 'Purdue'),
#  ('Boise St', 'Indiana'),
#  ('Boise St', 'Texas'),
#  ('Boise St', 'Buffalo'),
#  ('Boise St', 'Valparaiso'),
#  ('Boise St', 'Northeastern'),
#  ('Boise St', 'New Mexico St'),
#  ('Boise St', 'Hampton'),
#  ('Boise St', 'Manhattan'),
#  ('Boise St', 'Wisconsin'),
#  ('Boise St', 'Arizona'),
#  ('Boise St', 'Baylor'),
#  ('Boise St', 'North Carolina'),
#  ('Boise St', 'Arkansas'),
#  ('Boise St', 'Xavier'),
#  ('Boise St', 'VA Commonwealth'),
#  ('Boise St', 'Oregon'),
#  ('Boise St', 'Oklahoma St'),
#  ('Boise St', 'Ohio St'),
#  ('Boise St', 'BYU'),
#  ('Boise St', 'Mississippi'),
#  ('Boise St', 'Wofford'),
#  ('Boise St', 'Harvard'),
#  ('Boise St', 'Georgia St'),
#  ('Boise St', 'TX Southern'),
#  ('Boise St', 'Coastal Car'),
#  ('Dayton', 'Wyoming'),
#  ('Dayton', 'UC Irvine'),
#  ('Dayton', 'Albany NY'),
#  ('Dayton', 'Belmont'),
#  ('Dayton', 'Lafayette'),
#  ('Dayton', 'Duke'),
#  ('Dayton', 'Gonzaga'),
#  ('Dayton', 'Iowa St'),
#  ('Dayton', 'Georgetown'),
#  ('Dayton', 'Utah'),
#  ('Dayton', 'SMU'),
#  ('Dayton', 'Iowa'),
#  ('Dayton', 'San Diego St'),
#  ('Dayton', "St John's"),
#  ('Dayton', 'Davidson'),
#  ('Dayton', 'UCLA'),
#  ('Dayton', 'SF Austin'),
#  ('Dayton', 'E Washington'),
#  ('Dayton', 'UAB'),
#  ('Dayton', 'N Dakota St'),
#  ('Dayton', 'North Florida'),
#  ('Dayton', 'Robert Morris'),
#  ('Dayton', 'Kentucky'),
#  ('Dayton', 'Kansas'),
#  ('Dayton', 'Notre Dame'),
#  ('Dayton', 'Maryland'),
#  ('Dayton', 'West Virginia'),
#  ('Dayton', 'Butler'),
#  ('Dayton', 'Wichita St'),
#  ('Dayton', 'Cincinnati'),
#  ('Dayton', 'Purdue'),
#  ('Dayton', 'Indiana'),
#  ('Dayton', 'Texas'),
#  ('Dayton', 'Buffalo'),
#  ('Dayton', 'Valparaiso'),
#  ('Dayton', 'Northeastern'),
#  ('Dayton', 'New Mexico St'),
#  ('Dayton', 'Hampton'),
#  ('Dayton', 'Manhattan'),
#  ('Dayton', 'Wisconsin'),
#  ('Dayton', 'Arizona'),
#  ('Dayton', 'Baylor'),
#  ('Dayton', 'North Carolina'),
#  ('Dayton', 'Arkansas'),
#  ('Dayton', 'Xavier'),
#  ('Dayton', 'VA Commonwealth'),
#  ('Dayton', 'Oregon'),
#  ('Dayton', 'Oklahoma St'),
#  ('Dayton', 'Ohio St'),
#  ('Dayton', 'BYU'),
#  ('Dayton', 'Mississippi'),
#  ('Dayton', 'Wofford'),
#  ('Dayton', 'Harvard'),
#  ('Dayton', 'Georgia St'),
#  ('Dayton', 'TX Southern'),
#  ('Dayton', 'Coastal Car'),
#  ('Wyoming', 'UC Irvine'),
#  ('Wyoming', 'Albany NY'),
#  ('Wyoming', 'Belmont'),
#  ('Wyoming', 'Lafayette'),
#  ('Wyoming', 'Duke'),
#  ('Wyoming', 'Gonzaga'),
#  ('Wyoming', 'Iowa St'),
#  ('Wyoming', 'Georgetown'),
#  ('Wyoming', 'Utah'),
#  ('Wyoming', 'SMU'),
#  ('Wyoming', 'Iowa'),
#  ('Wyoming', 'San Diego St'),
#  ('Wyoming', "St John's"),
#  ('Wyoming', 'Davidson'),
#  ('Wyoming', 'UCLA'),
#  ('Wyoming', 'SF Austin'),
#  ('Wyoming', 'E Washington'),
#  ('Wyoming', 'UAB'),
#  ('Wyoming', 'N Dakota St'),
#  ('Wyoming', 'North Florida'),
#  ('Wyoming', 'Robert Morris'),
#  ('Wyoming', 'Kentucky'),
#  ('Wyoming', 'Kansas'),
#  ('Wyoming', 'Notre Dame'),
#  ('Wyoming', 'Maryland'),
#  ('Wyoming', 'West Virginia'),
#  ('Wyoming', 'Butler'),
#  ('Wyoming', 'Wichita St'),
#  ('Wyoming', 'Cincinnati'),
#  ('Wyoming', 'Purdue'),
#  ('Wyoming', 'Indiana'),
#  ('Wyoming', 'Texas'),
#  ('Wyoming', 'Buffalo'),
#  ('Wyoming', 'Valparaiso'),
#  ('Wyoming', 'Northeastern'),
#  ('Wyoming', 'New Mexico St'),
#  ('Wyoming', 'Hampton'),
#  ('Wyoming', 'Manhattan'),
#  ('Wyoming', 'Wisconsin'),
#  ('Wyoming', 'Arizona'),
#  ('Wyoming', 'Baylor'),
#  ('Wyoming', 'North Carolina'),
#  ('Wyoming', 'Arkansas'),
#  ('Wyoming', 'Xavier'),
#  ('Wyoming', 'VA Commonwealth'),
#  ('Wyoming', 'Oregon'),
#  ('Wyoming', 'Oklahoma St'),
#  ('Wyoming', 'Ohio St'),
#  ('Wyoming', 'BYU'),
#  ('Wyoming', 'Mississippi'),
#  ('Wyoming', 'Wofford'),
#  ('Wyoming', 'Harvard'),
#  ('Wyoming', 'Georgia St'),
#  ('Wyoming', 'TX Southern'),
#  ('Wyoming', 'Coastal Car'),
#  ('UC Irvine', 'Albany NY'),
#  ('UC Irvine', 'Belmont'),
#  ('UC Irvine', 'Lafayette'),
#  ('UC Irvine', 'Duke'),
#  ('UC Irvine', 'Gonzaga'),
#  ('UC Irvine', 'Iowa St'),
#  ('UC Irvine', 'Georgetown'),
#  ('UC Irvine', 'Utah'),
#  ('UC Irvine', 'SMU'),
#  ('UC Irvine', 'Iowa'),
#  ('UC Irvine', 'San Diego St'),
#  ('UC Irvine', "St John's"),
#  ('UC Irvine', 'Davidson'),
#  ('UC Irvine', 'UCLA'),
#  ('UC Irvine', 'SF Austin'),
#  ('UC Irvine', 'E Washington'),
#  ('UC Irvine', 'UAB'),
#  ('UC Irvine', 'N Dakota St'),
#  ('UC Irvine', 'North Florida'),
#  ('UC Irvine', 'Robert Morris'),
#  ('UC Irvine', 'Kentucky'),
#  ('UC Irvine', 'Kansas'),
#  ('UC Irvine', 'Notre Dame'),
#  ('UC Irvine', 'Maryland'),
#  ('UC Irvine', 'West Virginia'),
#  ('UC Irvine', 'Butler'),
#  ('UC Irvine', 'Wichita St'),
#  ('UC Irvine', 'Cincinnati'),
#  ('UC Irvine', 'Purdue'),
#  ('UC Irvine', 'Indiana'),
#  ('UC Irvine', 'Texas'),
#  ('UC Irvine', 'Buffalo'),
#  ('UC Irvine', 'Valparaiso'),
#  ('UC Irvine', 'Northeastern'),
#  ('UC Irvine', 'New Mexico St'),
#  ('UC Irvine', 'Hampton'),
#  ('UC Irvine', 'Manhattan'),
#  ('UC Irvine', 'Wisconsin'),
#  ('UC Irvine', 'Arizona'),
#  ('UC Irvine', 'Baylor'),
#  ('UC Irvine', 'North Carolina'),
#  ('UC Irvine', 'Arkansas'),
#  ('UC Irvine', 'Xavier'),
#  ('UC Irvine', 'VA Commonwealth'),
#  ('UC Irvine', 'Oregon'),
#  ('UC Irvine', 'Oklahoma St'),
#  ('UC Irvine', 'Ohio St'),
#  ('UC Irvine', 'BYU'),
#  ('UC Irvine', 'Mississippi'),
#  ('UC Irvine', 'Wofford'),
#  ('UC Irvine', 'Harvard'),
#  ('UC Irvine', 'Georgia St'),
#  ('UC Irvine', 'TX Southern'),
#  ('UC Irvine', 'Coastal Car'),
#  ('Albany NY', 'Belmont'),
#  ('Albany NY', 'Lafayette'),
#  ('Albany NY', 'Duke'),
#  ('Albany NY', 'Gonzaga'),
#  ('Albany NY', 'Iowa St'),
#  ('Albany NY', 'Georgetown'),
#  ('Albany NY', 'Utah'),
#  ('Albany NY', 'SMU'),
#  ('Albany NY', 'Iowa'),
#  ('Albany NY', 'San Diego St'),
#  ('Albany NY', "St John's"),
#  ('Albany NY', 'Davidson'),
#  ('Albany NY', 'UCLA'),
#  ('Albany NY', 'SF Austin'),
#  ('Albany NY', 'E Washington'),
#  ('Albany NY', 'UAB'),
#  ('Albany NY', 'N Dakota St'),
#  ('Albany NY', 'North Florida'),
#  ('Albany NY', 'Robert Morris'),
#  ('Albany NY', 'Kentucky'),
#  ('Albany NY', 'Kansas'),
#  ('Albany NY', 'Notre Dame'),
#  ('Albany NY', 'Maryland'),
#  ('Albany NY', 'West Virginia'),
#  ('Albany NY', 'Butler'),
#  ('Albany NY', 'Wichita St'),
#  ('Albany NY', 'Cincinnati'),
#  ('Albany NY', 'Purdue'),
#  ('Albany NY', 'Indiana'),
#  ('Albany NY', 'Texas'),
#  ('Albany NY', 'Buffalo'),
#  ('Albany NY', 'Valparaiso'),
#  ('Albany NY', 'Northeastern'),
#  ('Albany NY', 'New Mexico St'),
#  ('Albany NY', 'Hampton'),
#  ('Albany NY', 'Manhattan'),
#  ('Albany NY', 'Wisconsin'),
#  ('Albany NY', 'Arizona'),
#  ('Albany NY', 'Baylor'),
#  ('Albany NY', 'North Carolina'),
#  ('Albany NY', 'Arkansas'),
#  ('Albany NY', 'Xavier'),
#  ('Albany NY', 'VA Commonwealth'),
#  ('Albany NY', 'Oregon'),
#  ('Albany NY', 'Oklahoma St'),
#  ('Albany NY', 'Ohio St'),
#  ('Albany NY', 'BYU'),
#  ('Albany NY', 'Mississippi'),
#  ('Albany NY', 'Wofford'),
#  ('Albany NY', 'Harvard'),
#  ('Albany NY', 'Georgia St'),
#  ('Albany NY', 'TX Southern'),
#  ('Albany NY', 'Coastal Car'),
#  ('Belmont', 'Lafayette'),
#  ('Belmont', 'Duke'),
#  ('Belmont', 'Gonzaga'),
#  ('Belmont', 'Iowa St'),
#  ('Belmont', 'Georgetown'),
#  ('Belmont', 'Utah'),
#  ('Belmont', 'SMU'),
#  ('Belmont', 'Iowa'),
#  ('Belmont', 'San Diego St'),
#  ('Belmont', "St John's"),
#  ('Belmont', 'Davidson'),
#  ('Belmont', 'UCLA'),
#  ('Belmont', 'SF Austin'),
#  ('Belmont', 'E Washington'),
#  ('Belmont', 'UAB'),
#  ('Belmont', 'N Dakota St'),
#  ('Belmont', 'North Florida'),
#  ('Belmont', 'Robert Morris'),
#  ('Belmont', 'Kentucky'),
#  ('Belmont', 'Kansas'),
#  ('Belmont', 'Notre Dame'),
#  ('Belmont', 'Maryland'),
#  ('Belmont', 'West Virginia'),
#  ('Belmont', 'Butler'),
#  ('Belmont', 'Wichita St'),
#  ('Belmont', 'Cincinnati'),
#  ('Belmont', 'Purdue'),
#  ('Belmont', 'Indiana'),
#  ('Belmont', 'Texas'),
#  ('Belmont', 'Buffalo'),
#  ('Belmont', 'Valparaiso'),
#  ('Belmont', 'Northeastern'),
#  ('Belmont', 'New Mexico St'),
#  ('Belmont', 'Hampton'),
#  ('Belmont', 'Manhattan'),
#  ('Belmont', 'Wisconsin'),
#  ('Belmont', 'Arizona'),
#  ('Belmont', 'Baylor'),
#  ('Belmont', 'North Carolina'),
#  ('Belmont', 'Arkansas'),
#  ('Belmont', 'Xavier'),
#  ('Belmont', 'VA Commonwealth'),
#  ('Belmont', 'Oregon'),
#  ('Belmont', 'Oklahoma St'),
#  ('Belmont', 'Ohio St'),
#  ('Belmont', 'BYU'),
#  ('Belmont', 'Mississippi'),
#  ('Belmont', 'Wofford'),
#  ('Belmont', 'Harvard'),
#  ('Belmont', 'Georgia St'),
#  ('Belmont', 'TX Southern'),
#  ('Belmont', 'Coastal Car'),
#  ('Lafayette', 'Duke'),
#  ('Lafayette', 'Gonzaga'),
#  ('Lafayette', 'Iowa St'),
#  ('Lafayette', 'Georgetown'),
#  ('Lafayette', 'Utah'),
#  ('Lafayette', 'SMU'),
#  ('Lafayette', 'Iowa'),
#  ('Lafayette', 'San Diego St'),
#  ('Lafayette', "St John's"),
#  ('Lafayette', 'Davidson'),
#  ('Lafayette', 'UCLA'),
#  ('Lafayette', 'SF Austin'),
#  ('Lafayette', 'E Washington'),
#  ('Lafayette', 'UAB'),
#  ('Lafayette', 'N Dakota St'),
#  ('Lafayette', 'North Florida'),
#  ('Lafayette', 'Robert Morris'),
#  ('Lafayette', 'Kentucky'),
#  ('Lafayette', 'Kansas'),
#  ('Lafayette', 'Notre Dame'),
#  ('Lafayette', 'Maryland'),
#  ('Lafayette', 'West Virginia'),
#  ('Lafayette', 'Butler'),
#  ('Lafayette', 'Wichita St'),
#  ('Lafayette', 'Cincinnati'),
#  ('Lafayette', 'Purdue'),
#  ('Lafayette', 'Indiana'),
#  ('Lafayette', 'Texas'),
#  ('Lafayette', 'Buffalo'),
#  ('Lafayette', 'Valparaiso'),
#  ('Lafayette', 'Northeastern'),
#  ('Lafayette', 'New Mexico St'),
#  ('Lafayette', 'Hampton'),
#  ('Lafayette', 'Manhattan'),
#  ('Lafayette', 'Wisconsin'),
#  ('Lafayette', 'Arizona'),
#  ('Lafayette', 'Baylor'),
#  ('Lafayette', 'North Carolina'),
#  ('Lafayette', 'Arkansas'),
#  ('Lafayette', 'Xavier'),
#  ('Lafayette', 'VA Commonwealth'),
#  ('Lafayette', 'Oregon'),
#  ('Lafayette', 'Oklahoma St'),
#  ('Lafayette', 'Ohio St'),
#  ('Lafayette', 'BYU'),
#  ('Lafayette', 'Mississippi'),
#  ('Lafayette', 'Wofford'),
#  ('Lafayette', 'Harvard'),
#  ...]

# %%
#Adjusts variables so that they are all between 0 and 1
#i.e. adjusts to per-possession vs per-100-possessions
def adjust_variable(x,feat):
    return x[feat]/100.
    
for col in X_train.columns.tolist():
    if X_train[col].mean() > 1:
        X_train[col] = X_train.apply(lambda x: adjust_variable(x,col), axis=1)

for col in X_test.columns.tolist():
    if X_test[col].mean() > 1:
        X_test[col] = X_test.apply(lambda x: adjust_variable(x,col), axis=1)

# %%
best_features=['team_1_pythag', 'team_2_pythag', 'team_1_AdjOE', 'team_2_AdjOE',
       'team_1_AdjDE', 'team_2_AdjDE', 'team_2_Off_eFG_pct',
       'team_1_Off_OR_pct', 'team_2_Def_eFG_pct', 'team_1_Def_eFG_pct',
       'team_1_Off_eFG_pct', 'team_2_OppFG2Pct', 'team_2_Off_TO_pct',
       'team_1_OppFG2Pct', 'team_2_OppStlRate', 'team_1_Off_TO_pct',
       'team_1_FG2Pct', 'team_2_FG3Pct', 'team_2_Off_OR_pct',
       'team_1_OppFG3Pct', 'team_1_OppStlRate', 'team_2_FTPct',
       'team_2_BlockPct', 'team_2_Def_FT_rate', 'team_1_FTPct',
       'team_1_FG3Pct', 'team_1_BlockPct', 'team_1_Def_OR_pct',
       'team_2_OppFTPct', 'team_1_Def_TO_pct', 'team_2_Def_OR_pct',
       'team_2_OppBlockPct', 'team_1_OppBlockPct', 'team_1_OppFTPct',
       'team_2_OppF3GRate', 'team_2_OppARate', 'team_1_Def_FT_rate',
       'team_1_OppARate', 'team_1_OppF3GRate']

# %%
X_train = X_train[best_features]
X_test = X_test[best_features]

# %%
#Lets try logistic regression
#I found that a bagged logistic regression
#yields the lowest AUC
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss

logreg = BaggingClassifier(LogisticRegression())
logreg.fit(X_train,y_train,sample_weight=weights)

pred_probas=logreg.predict_proba(X_test)
pp_adj=[]

#I've determined that I can minimize my log loss by 
#adjusting each probability prediction 

#for i in range(len(pred_probas)):
#    pp_adj.append((pred_probas[i]**.88)/sum(pred_probas[i]**.88))

# %%
predictions1={}
for i in range(len(matchups)):
    predictions1[matchups[i]] = [pred_probas[i][1],pred_probas[i][0]]

# %%
predictions2={}
for i in range(len(matchups)):
    predictions2[matchups[i]] = [pp_adj[i][1],pp_adj[i][0]]

# %%
predictions1[('Hampton','Manhattan')]
# Out:
# [0.22649114049209257, 0.77350885950790738]

# %%
#Returns the predicted probabilities for 2 teams
def get_prediction(team1,team2):
    for p in predictions2:
        if p[0]==team1 and p[1]==team2:
            return predictions2[p]
        if p[1]==team1 and p[0]==team2:
            return [predictions2[p][1],predictions2[p][0]]

# %%
play_in_game_teams=['Dayton','Boise St','North Florida','Robert Morris']

# %%
first_round_teams=['Kentucky','Hampton','Cincinnati','Purdue',
                   'West Virginia','Buffalo','Maryland','Valparaiso',
                   'Butler','Texas','Notre Dame','Northeastern','Wichita St',
                   'Indiana','Kansas','New Mexico St','Wisconsin',
                   'Coastal Car','Oregon','Oklahoma St','Arkansas',
                   'Wofford','North Carolina','Harvard','Xavier',
                   'Mississippi','Baylor','Georgia St','VA Commonwealth',
                   'Ohio St','Arizona','TX Southern','Villanova','Lafayette',
                   'NC State','LSU','Northern Iowa','Wyoming','Louisville',
                   'UC Irvine','Providence','To be determined','Oklahoma','Albany NY',
                   'Michigan St','Georgia','Virginia','Belmont','Duke',
                   'To be determined','San Diego St',"St John's",'Utah',
                   'SF Austin','Georgetown','E Washington','SMU','UCLA',
                   'Iowa St','UAB','Iowa','Davidson','Gonzaga','N Dakota St']

# %%
#Function that divides values in dictionary by a divisor
def get_percent(count,divisor):
    for key in count:
        count[key]=round(count[key]/divisor,4)
        
    return count

# %%
def get_next_round(current_round_teams):
    next_round_teams=[]
    for i in range(0,len(current_round_teams),2):
        team1=current_round_teams[i]
        team2=current_round_teams[i+1]
        thres=get_prediction(team1,team2)[0]
        a=np.random.random()
        if a < thres:
            next_round_teams.append(team1)
        if a > thres:
            next_round_teams.append(team2)
            
    return next_round_teams

# %% [raw]
# #Runs 50,000 simulations to find the probability of each
# #team making each round
#
# second_round_total=[]
# sweet_16_total=[]
# elite_8_total=[]
# final_4_total=[]
# finals_total=[]
# winners_total=[]
# counter=0.0
# for i in range(50000):
#
#     pig_winners=[]
#     for i in range(0,len(play_in_game_teams),2):
#         team1=play_in_game_teams[i]
#         team2=play_in_game_teams[i+1]
#         thres=get_prediction(team1,team2)[0]
#         a=np.random.random()
#         if a < thres:
#             pig_winners.append(team1)
#         if a > thres:
#             pig_winners.append(team2)
#
#     first_round_teams=['Kentucky','Hampton','Cincinnati','Purdue',
#                        'West Virginia','Buffalo','Maryland','Valparaiso',
#                        'Butler','Texas','Notre Dame','Northeastern','Wichita St',
#                        'Indiana','Kansas','New Mexico St','Wisconsin',
#                        'Coastal Car','Oregon','Oklahoma St','Arkansas',
#                        'Wofford','North Carolina','Harvard','Xavier',
#                        'Mississippi','Baylor','Georgia St','VA Commonwealth',
#                        'Ohio St','Arizona','TX Southern','Villanova','Lafayette',
#                        'NC State','LSU','Northern Iowa','Wyoming','Louisville',
#                        'UC Irvine','Providence',pig_winners[0],'Oklahoma','Albany NY',
#                        'Michigan St','Georgia','Virginia','Belmont','Duke',
#                        pig_winners[1],'San Diego St',"St John's",'Utah',
#                        'SF Austin','Georgetown','E Washington','SMU','UCLA',
#                        'Iowa St','UAB','Iowa','Davidson','Gonzaga','N Dakota St']
#
#
#     second_round_teams=get_next_round(first_round_teams)
#     second_round_total+=second_round_teams
#
#     sweet_16_teams=get_next_round(second_round_teams)
#     sweet_16_total+=sweet_16_teams
#
#     elite_8_teams=get_next_round(sweet_16_teams)
#     elite_8_total+=elite_8_teams
#
#     final_4_teams=get_next_round(elite_8_teams)
#     final_4_total+=final_4_teams
#
#     finals_teams=get_next_round(final_4_teams)
#     finals_total+=finals_teams
#
#     winner=get_next_round(finals_teams)
#     winners_total+=winner
#
#
#     counter+=1
#     if np.mod(counter,1000)==0:
#         print str(int(counter)),' iterations'
#
#
# second_round_probs=get_percent(Counter(second_round_total),counter)
# sweet_16_probs=get_percent(Counter(sweet_16_total),counter)
# elite_8_probs=get_percent(Counter(elite_8_total),counter)
# final_4_probs=get_percent(Counter(final_4_total),counter)
# finals_probs=get_percent(Counter(finals_total),counter)
# winner_probs=get_percent(Counter(winners_total),counter)

# %%
get_prediction('Virginia','Michigan St')
# Out:
# [0.69870862616786511, 0.30129137383213495]

# %%
sweet_16_probs['New Mexico St']
# Out:
# 0.0354
